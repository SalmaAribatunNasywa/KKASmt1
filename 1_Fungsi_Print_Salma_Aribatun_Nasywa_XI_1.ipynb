# %% [markdown]
# <a href="https://colab.research.google.com/github/SalmaAribatunNasywa/KKASmt1/blob/main/1_Fungsi_Print_Salma_Aribatun_Nasywa_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Menampilkan Teks Bebas

# %%
print  ( "Halo dunia" )
# Out:
# Halo dunia

# %%
print ("Selamat datang di Python")
# Out:
# Selamat datang di Python

# %%
print ('Salma Aribatun Nasywa')
# Out:
# Salma Aribatun Nasywa

# %% [markdown]
# # Variabel

# %%
BB = 50
print(BB)
# Out:
# 50

# %%
UMUR = ⁶16
print(UMUR)
# Out:
# 16

# %%
print ( f "umur saya  { UMUR }  tahun" )
# Out:
# umur saya 16 tahun

# %% [markdown]
# # Menampilkan teks bebas dan variabel

# %%
Harga_telur =  27000

print ( "Harga telur per 1 kg adalah" ,  harga_telur )
# Out:
# Harga telur per 1 kg adalah 27000

# %%
nama_pembeli = "Salma"

print("Nama pembeli telur adalah " + str(nama_pembeli))
# Out:
# Nama pembeli telur adalah Salma

# %%
Harga_telur = 27000

print("Harga telur 1 kg adalah " + str ( harga_telur ))
# Out:
# Harga telur 1 kg adalah 27000

# %% [markdown]
# #Escape Character

# %%
print("Nama : Salma Aribatun Nasywa")
print("Kelas : XI-1")
print("Nomor absen : 31")
# Out:
# Nama : Salma Aribatun Nasywa
# Kelas : X1-1
# Nomor absen : 31

# %%
print("Nama\t\t: Salma Aribatun Nasywa\nKelas\t\t: XI-1\nNomor absen\t: 31")
# Out:
# Nama		: Salma Aribatun Nasywa
# Kelas		: XI-1
# Nomor absen	: 31

# %%
print("""Nama : Salma Aribatun Nasywa
Kelas : XI-1
Nomor Absen : 31""")
# Out:
# Nama : Salma Aribatun Nasywa
# Kelas : XI-1
# Nomor Absen : 31

# %% [markdown]
# Latihan Soal
# 1. Tampilkan teks bebas:Hari ini saya bahagia belajar bahasa python
# 2. Tampilkan nilai variabel:mata_pelajaran_favorit = Kode dan Kecerdasan Buatan
# 3. Tampilkan nilai variabel:nilai_kka = 100
# 4. Tampilkan teks bebas dan nilai variabel dengan tiga mode (f string,"+",","): "Nilai KKA saya adalah {nilai_kka} loh!"

# %%
print("Hari ini saya bahagia belajar bahasa python")
# Out:
# Hari ini saya bahagia belajar bahasa python

# %%
mata_pelajaran_favorit = "Bahasa Arab"
print(mata_pelajaran_favorit)
# Out:
# Bahasa Arab

# %%
nilai_kka = 100
print(nilai_kka)
# Out:
# 100

# %%
nilai_kka = 98
print(f"Nilai KKA saya adalah {nilai_kka} loh!")
# Out:
# Nilai KKA saya adalah 98 loh!

# %%
nilai_kka = 98
print("Nilai KKA saya adalah", nilai_kka, "loh!")
# Out:
# Nilai KKA saya adalah 98 loh!

# %%
nilai_kka =  98
print ( "Nilai KKA saya adalah "  +  str ( nilai_kka )  +  " loh!" )
# Out:
# Nilai KKA saya adalah 98 loh!

# %%
print ('Ja\'far Shodiq')
# Out:
# Ja'far Shodiq

# %%
print ("Ja'far Shodiq")
# Out:
# Ja'far Shodiq

# %%
print ("Bu Shinta berkata, \"Semua harus menyimak pelajaran.\"")
# Out:
# Bu Shinta berkata, "Semua harus menyimak pelajaran."

# %%
print ('Bu Shinta berkata, "Semua harus menyimak pelajaran." ')
# Out:
# Bu Shinta berkata, "Semua harus menyimak pelajaran."

# %%
print ("Lokasi file video karnaval ada di D:\\Karnaval 2025\\M4")
# Out:
# Lokasi file video karnaval ada di D:\Karnaval 2025\M4

# %% [markdown]
# #Parameter Fungsi Print

# %%
Tahun = 2009
Bulan = "Oktober"
Tanggal = 23

print (Tanggal, end=" ")
print (Bulan, end=" ")
print (Tahun)
# Out:
# 23 Oktober 2009

# %%
Tahun = 2009
Bulan = "Oktober"
Tanggal = 23

print (Tanggal, Bulan, Tahun, sep="/")
# Out:
# 23/Oktober/2009

# %% [markdown]
# Latihan :
#
# Tanggal-Bulan-Tahun

# %%
Tahun = 2009
Bulan = "Oktober"
Tanggal = 23

print (Tanggal, Bulan, Tahun, sep= "-")
# Out:
# 23-Oktober-2009

# %%
Nama_depan = "Salma"
Nama_belakang = "Aribatun Nasywa"

print (Nama_depan,Nama_belakang)
# Out:
# Salma Aribatun Nasywa

# %%
Nama_depan = "Salma"
Nama_belakang = "Aribatun Nasywa"

print (Nama_depan, end=" ")
print (Nama_belakang)
# Out:
# Salma Aribatun Nasywa

# %% [markdown]
# #Tugas

# %%
print   ( 'Bu Shinta berkata, "Berikut adalah judul pelajara n  hari Senin Rabu silahkan di simpan di la p top masing-masing di folder local disk D:\\Jadwa l Pelajaran\\Kelas XI Semester 1"' )
print   ( "\nJadwal Pelajaran Mingguan" )
print   ( "=======================================================" )
print   ( "Jam\tSenin\t\tSelasa\t\tRabu" )
print   ( "Jam 1\tMatematika\tBahasa\t\tInformatika" )
print   ( "Jam 2\tBahasa Ing.\tSejarah\t\tMa'rifatullah" )
print   ( "Jam 3\tInformatika\tOlahraga\tBiologi" )
# Out:
# Bu Shinta berkata, "Berikut adalah judul pelajara n  hari Senin Rabu silahkan di simpan di la p top masing-masing di folder local disk D:\Jadwa l Pelajaran\Kelas XI Semester 1"
#
# Jadwal Pelajaran Mingguan
# =======================================================
# Jam	Senin		Selasa		Rabu
# Jam 1	Matematika	Bahasa		Informatika
# Jam 2	Bahasa Ing.	Sejarah		Ma'rifatullah
# Jam 3	Informatika	Olahraga	Biologi

# %%
Nama_1 = "Naufal"
Nama_2 = "Favian"
Nama_3 = "Humaira"

print (Nama_1, Nama_2, Nama_3, Nama_1, sep="~")
# Out:
# Naufal~Favian~Humaira~Naufal

# %%
Nama_1 = "Naufal"
Nama_2 = "Favian"
Nama_3 = "Humaira"

print (Nama_1, end="~")
print (Nama_2)
print (Nama_3, end="~")
print (Nama_2)
# Out:
# Naufal~Favian
# Humaira~Favian
