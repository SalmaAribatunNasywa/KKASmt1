# %% [markdown]
# <a href="https://colab.research.google.com/github/SalmaAribatunNasywa/KKASmt1/blob/main/2_Tipe_Variabel_Salma_A_N_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Salma Aribatun Nasywa
#
# Kelas : XI-1
#
# No.Absen : 32

# %% [markdown]
# #Konsep Dasar

# %%
email_user_1 =  "salmaaribatunnasywa_2025@gmail.com"
 print  ( email_user_1 )
# Out:
# salmaaribatunnasywa_2025@gmail.com

# %%
sabun_lifeboy =  15000
 cetakan  ( sabun_lifeboy )
# Out:
# 15000

# %%
print(sabun_lifeboy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
# Penulisan Variabel hanya boleh menggunakan huruf , angka dan underscore
# Tidak boleh menggunakan spasi

nama siswa =  "Afa"
print ( nama siswa )
# Out:
#   File "/tmp/ipython-input-241493974.py", line 4
#     nama siswa =  "Afa"
#          ^
# SyntaxError: invalid syntax

# %%
# Tidak boleh di awal dengan angka

1 _nama_siswa = "Afa"
print( 1 _nama_siswa )
# Out:
#   File "/tmp/ipython-input-3292163243.py", line 3
#     1 _nama_siswa = "Afa"
#       ^
# SyntaxError: invalid syntax

# %%
# Penulisan Variabel itu case sensitif /  capslock sensitif

nama_siswa_1 = "Afa"
print( Nama_siswa_1 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1807450463.py in <cell line: 0>()
#       2
#       3 nama_siswa_1 = "Afa"
# ----> 4 print( Nama_siswa_1 )
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
# Dilarang menggunakan kata kunci dalam Bahasa Python

prin = "Afa"
print (prin)
# Out:
# Afa

# %%
end =  "Naufal"
print (end)
# Out:
# Naufal

# %%
# Deskriptif

_ = "Favian"
print (_)
# Out:
# Favian

# %%
# Tidak boleh pakai kata kunci python
# Kalau eror, harus disconnect dulu

prin = "Devin"
print (prin)
# Out:
# Devin

# %% [markdown]
# #Assignment

# %% [markdown]
# ##Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"

print (nama_siswa_2)
print (nama_siswa_3)
# Out:
# Dhapne
# Farel

# %% [markdown]
# ##Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %% [markdown]
# ##Assignment ke Banyak Variabel Sekaligus

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# #Latihan Soal : Harga Barang di Swalayan
#
# Seorang kasir sedang mencatat harga beberapa barang di Swalayan. Bantulah kasir dengan membuat program Phyton yang melakukan.

# %% [markdown]
# ##Single Assignment

# %%
harga_susu = 15000
harga_roti = 12000
harga_telur = 24000

print (harga_susu)
print (harga_roti)
print (harga_telur)
# Out:
# 15000
# 12000
# 24000

# %% [markdown]
# ##Multiple Assignment

# %%
harga_gula, harga_minyak = 14000, 20000

print (harga_gula)
print (harga_minyak)
# Out:
# 14000
# 20000

# %% [markdown]
# ##Pengisian Nilai Sama

# %%
harga_mie_ayam = harga_mie_soto = harga_mie_kari = 3500

print (harga_mie_ayam)
print (harga_mie_soto)
print (harga_mie_kari)
# Out:
# 3500
# 3500
# 3500

# %% [markdown]
# ##Swap (Tukar Nilai)

# %%
harga_roti = 15000
harga_susu = 12000

print (harga_roti)
print (harga_susu)
# Out:
# 15000
# 12000

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
# Mengalami Diskon

harga_telur = 24000 - 2000
harga_minyak = 20000 + 3000

print (harga_telur)
print (harga_minyak)
# Out:
# 22000
# 23000

# %% [markdown]
# #Arimatika

# %%
print ("5000*3")
# Out:
# 5000*3

# %%
# Operand tanpa di simpan dalam variabel

print (5000*3)
# Out:
# 15000

# %%
# Simpan operand ke dalam variabel

harga_kojek = 6000
banyak_porsi = 3

print (harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
# Simpan hasil operasi ke dalam variabel


harga_total_kojek = 3000*3

print (harga_total_kojek)
# Out:
# 9000

# %%
# Simpan nilai operasi dan hasil operasi ke dalam variabel

harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print (harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print (uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Soal
#
# Satu kardus berisi 24 botol minum. Jika ada 3 kardus, berapa jumlah botol?

# %%
print (24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print (total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print (banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65

type (usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "Salma"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8

type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
#Tipe data masih string dan harus di-convert ke integer/float
luas = panjang*lebar

print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3753996002.py in <cell line: 0>()
#       1 #Tipe data masih string dan harus di-convert ke integer/float
# ----> 2 luas = panjang*lebar
#       3
#       4 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 4
# Masukkan lebar persegi: 10
# Luas persegi panjang adalah 40 cm^2

# %% [markdown]
# #Soal Menghitung Volume Balok (dalam cm^2)
#
# Buatlah program Phyton untuk menghitung volume balok berdasarkan input pengguna.
#
# Gunakan rumus : V= p×l*t

# %%
panjang_3 = input()
# Out:
# 10

# %%
print(panjang_3)
# Out:
# 10

# %%
lebar_3 = input()
# Out:
# 5

# %%
print(lebar_3)
# Out:
# 5

# %%
tinggi_3 = input()
# Out:
# 4

# %%
print(tinggi_3)
# Out:
# 4

# %%
panjang_3 =int(panjang_3)

# %%
lebar_3 = int(lebar_3)

# %%
tinggi_3 = int (tinggi_3)

# %%
panjang_3 = int(input("Masukkan panjang balok: "))
lebar_3 = int(input("Masukkan lebar balok: "))
tinggi_3 = int(input("Masukkan lebar balok: "))

volume_3 = panjang_3*lebar_3*tinggi_3

print(f"Volume balok adalah {volume_3} cm^2")
# Out:
# Masukkan panjang balok: 10
# Masukkan lebar balok: 5
# Masukkan lebar balok: 4
# Volume balok adalah 200 cm^2

# %% [markdown]
# #Konversi Tipe Data

# %%
a = 3
print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print(b)

b = bool(b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool(c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e = "false"
print(e)
type(e)
# Out:
# false
# str

# %% [markdown]
# #Operator Perbanding

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 5)
# Out:
# False

# %%
print(8 == 8)
# Out:
# True

# %%
print(1 !=1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>c)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print (8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125 >= iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
tinggi_min = 165
berat_badan_min = 50
umur_max = 23

tinggi_farel = 170
berat_badan_farel = 55
umur_farel =23

print(tinggi_farel >= tinggi_min and berat_badan_farel >= berat_badan_min and umur_farel <= umur_max)
# Out:
# True
